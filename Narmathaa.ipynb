# %% [markdown]
# # Descriptive Analysis and Statistics of the whole Cluster dataset:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import get_data
import os 
os.getcwd()
# Out:
# 'C:\\Users\\narma\\Desktop\\302C GitHub\\covid19-public'

# %%
# To read the original Covid dataset from the GitHub
dataset = get_data.read_csv('epidemic','clusters') 
df_1 = get_data.convert_state_code(dataset) #------States column converted from integer to string
df_1
# Out:
#                                        cluster  \
# 0                          KLUSTER WARGA JEPUN
# 1                                  KLUSTER UDA
# 2     KLUSTER KEAGAMAAN (TABLIGH SRI PETALING)
# 3                    KLUSTER TABLIGH NEW DELHI
# 4                                KLUSTER AIROD
# ...                                        ...
# 7151           KLUSTER DUA JALAN PADANG GOLF 3
# 7152               KLUSTER JALAN PADANG GOLF 5
# 7153                       KLUSTER DAH BATU 19
# 7154                       KLUSTER DAH TERABAK
# 7155                  KLUSTER JALAN KAKI BUKIT
#
#                                                   state       district  \
# 0                                     W.P. KUALA LUMPUR  LEMBAH PANTAI
# 1     JOHOR,NEGERI SEMBILAN,SELANGOR,W.P. KUALA LUMP...       PELBAGAI
# 2                                            not stated       PELBAGAI
# 3     NEGERI SEMBILAN,SELANGOR,W.P. KUALA LUMPUR,W.P...       PELBAGAI
# 4                                                PAHANG        KUANTAN
# ...                                                 ...            ...
# 7151                                           SELANGOR  HULU SELANGOR
# 7152                                           SELANGOR  HULU SELANGOR
# 7153                                              KEDAH    KUBANG PASU
# 7154                                              KEDAH    KUBANG PASU
# 7155                                             PERLIS         KANGAR
#
#      date_announced date_last_onset   category  status  cases_new  \
# 0        2020-03-01      2020-03-09     import   ended          0
# 1        2020-03-04      2020-03-01     import   ended          0
# 2        2020-03-13      2020-03-11  religious   ended          0
# 3        2020-03-16      2020-03-20     import   ended          0
# 4        2020-03-31      2020-03-31  workplace   ended          0
# ...             ...             ...        ...     ...        ...
# 7151     2022-11-26      2022-11-25   highRisk  active          0
# 7152     2022-11-27      2022-11-26   highRisk  active          0
# 7153     2022-11-27      2022-12-04  education  active         12
# 7154     2022-12-01      2022-12-04  education  active          2
# 7155     2022-12-02      2022-12-03  education  active          0
#
#       cases_total  cases_active  tests  icu  deaths  recovered  \
# 0               3             0    267    0       0          3
# 1             144             0   1864    0       2        142
# 2            2022             0  42023    0      34       1988
# 3              24             0     57    0       0         24
# 4              65             0    734    0       0         65
# ...           ...           ...    ...  ...     ...        ...
# 7151           25            25     35    0       0          0
# 7152            3             3     13    0       0          0
# 7153           84            84    214    0       0          0
# 7154           89            89    702    0       0          0
# 7155           12            12     12    0       0          0
#
#                                              summary_bm  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7151  Kluster ini merupakan kluster berulang untuk k...
# 7152  Kluster ini merupakan kluster berulang kali ke...
# 7153  Kluster ini melibatkan pelajar-pelajar sebuah ...
# 7154  Kluster ini melibatkan pelajar-pelajar sebuah ...
# 7155  Kluster ini melibatkan pelajar-pelajar sebuah ...
#
#                                              summary_en
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7151  This is a third recurring cluster involving re...
# 7152  This cluster is the fifth repeated cluster inv...
# 7153  This cluster involves students from an educati...
# 7154  This cluster involves the students of an educa...
# 7155  This cluster involves the students of an educa...
#
# [7156 rows x 16 columns]

# %%
#To view the 8 statistical properties of each attribute
df_1.describe()
# Out:
#          cases_new  cases_total  cases_active         tests          icu  \
# count  7156.000000  7156.000000   7156.000000   7156.000000  7156.000000
# mean      0.001956    78.429290      0.355226    318.667552     0.001677
# std       0.143809   199.387438      5.303520   1086.949175     0.040919
# min       0.000000     2.000000      0.000000      3.000000     0.000000
# 25%       0.000000    18.000000      0.000000     51.000000     0.000000
# 50%       0.000000    35.000000      0.000000    117.000000     0.000000
# 75%       0.000000    73.000000      0.000000    282.250000     0.000000
# max      12.000000  7205.000000    197.000000  42100.000000     1.000000
#
#             deaths    recovered
# count  7156.000000  7156.000000
# mean      0.272359    77.770542
# std       1.288240   199.073056
# min       0.000000     0.000000
# 25%       0.000000    18.000000
# 50%       0.000000    35.000000
# 75%       0.000000    73.000000
# max      37.000000  7204.000000

# %% [markdown]
# To view the class distribution for the 'status' column and 'category' column

# %%
df_1.groupby('status').size() #----To view the number of active and ended cases
# Out:
# status
# active      57
# ended     7099
# dtype: int64

# %%
df_1.groupby('category').size() #----To view the number of categories
# Out:
# category
# community          1732
# detentionCentre     162
# education           975
# highRisk            486
# import               53
# religious           181
# workplace          3567
# dtype: int64

# %% [markdown]
# # Analysing the Death distribution according to each category

# %%
df_1['deaths'].sum() #-----To calculate the total number of deaths in the original dataset
# Out:
# 1949

# %%
# To determine the cluster with maximum number of deaths
maxValues = df_1[['deaths']].max()
maxValues
maxDeaths = df_1.loc[df_1['deaths'] == int(maxValues)]
maxDeaths
# Out:
#                      cluster         state  \
# 2382  KLUSTER RANTAU KENANGA  PAHANG,PERAK
#
#                                                district date_announced  \
# 2382  MARAN, BERA, TEMERLOH, JERANTUT, KUANTAN, BENT...     2021-06-08
#
#      date_last_onset   category status  cases_new  cases_total  cases_active  \
# 2382      2021-07-27  community  ended          0          568             0
#
#       tests  icu  deaths  recovered summary_bm summary_en
# 2382   4772    0      37        531        NaN        NaN

# %% [markdown]
# To check number of active cases and total number of deaths recorded in the active cases

# %%
df_active = (df_1.loc[df_1['status'] == 'active']) #------To view the active clusters in the dataset
df_active
# Out:
#                                       cluster              state  \
# 7088                     KLUSTER JALAN REJANG  W.P. KUALA LUMPUR
# 7092                   KLUSTER MAYANG PASIR 2       PULAU PINANG
# 7098                KLUSTER CHANGKAT BERANGAN              PERAK
# 7100             KLUSTER KM132 AYER PA’ABAS 2             MELAKA
# 7101            KLUSTER JALAN SEREMBAN TIGA 2    NEGERI SEMBILAN
# 7102              KLUSTER JALAN KAMPUNG PILIN    NEGERI SEMBILAN
# 7105             KLUSTER JALAN SHAH BANTING 3           SELANGOR
# 7106        KLUSTER INDUSTRI RAWANG BESTARI 3           SELANGOR
# 7107               KLUSTER JALAN BUKIT IDAMAN           SELANGOR
# 7108                      KLUSTER JALAN SAYUR  W.P. KUALA LUMPUR
# 7109            KLUSTER JALAN MASJID NEGERI 2       PULAU PINANG
# 7110                KLUSTER JALAN TAMAN TASIK              PERAK
# 7111                    KLUSTER TAMAN KEMUMIN           KELANTAN
# 7112         KLUSTER DUA JALAN YAACOB LATIF 2  W.P. KUALA LUMPUR
# 7113                KLUSTER JALAN EMPANG BATU             MELAKA
# 7114                KLUSTER BATU SATU SABAK 2           SELANGOR
# 7115           KLUSTER JALAN SELADANG PASAR 3  W.P. KUALA LUMPUR
# 7116                   KLUSTER PERSIARAN GOLF           SELANGOR
# 7117           KLUSTER DUA JALAN KASTURI SATU           SELANGOR
# 7118                  KLUSTER TANJUNG LABUH 2              JOHOR
# 7119                      KLUSTER SERI BOTA 2              PERAK
# 7120               KLUSTER JALAN DATO HARUN 2             MELAKA
# 7121                KLUSTER DAH JALAN SERDANG              KEDAH
# 7122     KLUSTER JALAN SULTAN AHMADDIN SHAH 2              PERAK
# 7123              KLUSTER JALAN LEONG YEW KOH  W.P. KUALA LUMPUR
# 7124           KLUSTER JALAN SRI HARTAMAS DUA  W.P. KUALA LUMPUR
# 7125                  KLUSTER DESA DARUL NAIM           KELANTAN
# 7126             KLUSTER JALAN SRI PERMAISURI  W.P. KUALA LUMPUR
# 7127                     KLUSTER JALAN LABU 2    NEGERI SEMBILAN
# 7128                  KLUSTER JALAN SIKAMAT 2    NEGERI SEMBILAN
# 7129         KLUSTER INDUSTRI KENANGA LAPAN 2           SELANGOR
# 7130                    KLUSTER JALAN KOLAM 2  W.P. KUALA LUMPUR
# 7131      KLUSTER PERSIARAN DATO SHAMSUDDIN 4  W.P. KUALA LUMPUR
# 7132      KLUSTER INDUSTRI LORONG KELULI SATU           SELANGOR
# 7133           KLUSTER TIGA JALAN KOTA RAJA 2           SELANGOR
# 7134                   KLUSTER LORONG KAPAL 3       PULAU PINANG
# 7135        KLUSTER JALAN INTAN TIGA KAMPAR 2              PERAK
# 7136        KLUSTER TIANG DUA BUKIT LINTANG 2             MELAKA
# 7137      KLUSTER JALAN PENDIDIKAN MALAWATI 3           SELANGOR
# 7138  KLUSTER JALAN TUN RAZAK KUALA KANGSAR 2              PERAK
# 7139           KLUSTER LORONG BATU LANCHANG 2       PULAU PINANG
# 7140       KLUSTER EMPAT JALAN YAACOB LATIF 3  W.P. KUALA LUMPUR
# 7141              KLUSTER JALAN BEMBAN SERKAM             MELAKA
# 7142     KLUSTER JALAN TUANKU SYED SIRAJUDDIN             PERLIS
# 7143                      KLUSTER DAH BATU 22              KEDAH
# 7144             KLUSTER JALAN DAHLIA EMPAT 2           SELANGOR
# 7145                KLUSTER JALAN RAJA MUDA 2  W.P. KUALA LUMPUR
# 7146       KLUSTER DUA JALAN DATO AHMAD YUNUS              PERAK
# 7147       KLUSTER DUA JALAN PERAK GEORGETOWN       PULAU PINANG
# 7148             KLUSTER JALAN BATU GANTUNG 2       PULAU PINANG
# 7149      KLUSTER JALAN BERTAM KEPALA BATAS 2       PULAU PINANG
# 7150          KLUSTER JALAN PUNCAK ISKANDAR 2              PERAK
# 7151          KLUSTER DUA JALAN PADANG GOLF 3           SELANGOR
# 7152              KLUSTER JALAN PADANG GOLF 5           SELANGOR
# 7153                      KLUSTER DAH BATU 19              KEDAH
# 7154                      KLUSTER DAH TERABAK              KEDAH
# 7155                 KLUSTER JALAN KAKI BUKIT             PERLIS
#
#                                           district date_announced  \
# 7088                                    TITIWANGSA     2022-10-27
# 7092  BARAT DAYA, TIMUR LAUT, SEBERANG PERAI UTARA     2022-10-31
# 7098                     HULU PERAK, KUALA KANGSAR     2022-11-03
# 7100                     ALOR GAJAH, MELAKA TENGAH     2022-11-04
# 7101                                      SEREMBAN     2022-11-04
# 7102                                        REMBAU     2022-11-04
# 7105                                  KUALA LANGAT     2022-11-06
# 7106                         GOMBAK, HULU SELANGOR     2022-11-08
# 7107                         GOMBAK, HULU SELANGOR     2022-11-08
# 7108                                        CHERAS     2022-11-08
# 7109                                    TIMUR LAUT     2022-11-08
# 7110                        LARUT, MATANG & SELAMA     2022-11-08
# 7111                                    KOTA BHARU     2022-11-08
# 7112                            CHERAS, TITIWANGSA     2022-11-08
# 7113                                    ALOR GAJAH     2022-11-08
# 7114                                  SABAK BERNAM     2022-11-09
# 7115                                        CHERAS     2022-11-09
# 7116                                      PETALING     2022-11-09
# 7117                                 HULU SELANGOR     2022-11-09
# 7118                                    BATU PAHAT     2022-11-09
# 7119                                  PERAK TENGAH     2022-11-09
# 7120                                    ALOR GAJAH     2022-11-09
# 7121                                 BANDAR BAHARU     2022-11-10
# 7122                                  PERAK TENGAH     2022-11-10
# 7123                                        KEPONG     2022-11-10
# 7124                                        KEPONG     2022-11-10
# 7125                                    KOTA BHARU     2022-11-10
# 7126                                        CHERAS     2022-11-10
# 7127                                      SEREMBAN     2022-11-10
# 7128                                      SEREMBAN     2022-11-10
# 7129                                 HULU SELANGOR     2022-11-11
# 7130                                CHERAS, KEPONG     2022-11-11
# 7131                            KEPONG, TITIWANGSA     2022-11-11
# 7132                                         KLANG     2022-11-12
# 7133                                         KLANG     2022-11-12
# 7134                          SEBERANG PERAI UTARA     2022-11-13
# 7135                                        KAMPAR     2022-11-13
# 7136                                 MELAKA TENGAH     2022-11-14
# 7137                                KUALA SELANGOR     2022-11-14
# 7138                                 KUALA KANGSAR     2022-11-14
# 7139                                    TIMUR LAUT     2022-11-15
# 7140                                        CHERAS     2022-11-15
# 7141                                         JASIN     2022-11-15
# 7142                                        KANGAR     2022-11-16
# 7143                                           YAN     2022-11-16
# 7144                                        SEPANG     2022-11-17
# 7145                                    TITIWANGSA     2022-11-17
# 7146                                       MANJUNG     2022-11-19
# 7147                                    TIMUR LAUT     2022-11-20
# 7148                        TIMUR LAUT, BARAT DAYA     2022-11-20
# 7149                          SEBERANG PERAI UTARA     2022-11-20
# 7150                                  PERAK TENGAH     2022-11-22
# 7151                                 HULU SELANGOR     2022-11-26
# 7152                                 HULU SELANGOR     2022-11-27
# 7153                                   KUBANG PASU     2022-11-27
# 7154                                   KUBANG PASU     2022-12-01
# 7155                                        KANGAR     2022-12-02
#
#      date_last_onset         category  status  cases_new  cases_total  \
# 7088      2022-11-07        education  active          0           44
# 7092      2022-11-22        workplace  active          0          110
# 7098      2022-11-10        education  active          0          144
# 7100      2022-11-16        education  active          0          204
# 7101      2022-11-16        education  active          0           84
# 7102      2022-11-17        education  active          0          108
# 7105      2022-11-23        education  active          0          125
# 7106      2022-11-07        workplace  active          0           10
# 7107      2022-11-07        workplace  active          0            6
# 7108      2022-11-07        education  active          0            7
# 7109      2022-11-10         highRisk  active          0           48
# 7110      2022-11-13        education  active          0           19
# 7111      2022-11-14         highRisk  active          0           41
# 7112      2022-11-16        education  active          0           52
# 7113      2022-11-16        education  active          0           82
# 7114      2022-11-08        education  active          0           33
# 7115      2022-11-08        education  active          0           41
# 7116      2022-11-08        education  active          0           16
# 7117      2022-11-08        education  active          0            5
# 7118      2022-11-09        education  active          0           15
# 7119      2022-11-14        education  active          0           29
# 7120      2022-11-16        education  active          0           52
# 7121      2022-11-09  detentionCentre  active          0           43
# 7122      2022-11-09        education  active          0           19
# 7123      2022-11-09        education  active          0            8
# 7124      2022-11-09        education  active          0           10
# 7125      2022-11-09        education  active          0           32
# 7126      2022-11-13        education  active          0           35
# 7127      2022-11-17        education  active          0          112
# 7128      2022-11-23        education  active          0           32
# 7129      2022-11-10        workplace  active          0           14
# 7130      2022-11-10        education  active          0           33
# 7131      2022-11-10        education  active          0           73
# 7132      2022-11-11        workplace  active          0           13
# 7133      2022-11-11        education  active          0           48
# 7134      2022-11-12         highRisk  active          0           23
# 7135      2022-11-25         highRisk  active          0           13
# 7136      2022-11-13  detentionCentre  active          0           34
# 7137      2022-11-16        education  active          0           76
# 7138      2022-11-20        education  active          0           53
# 7139      2022-11-16         highRisk  active          0           12
# 7140      2022-11-16        education  active          0           23
# 7141      2022-11-16        education  active          0           48
# 7142      2022-11-15        education  active          0           14
# 7143      2022-11-17        education  active          0           85
# 7144      2022-11-16        education  active          0           20
# 7145      2022-11-16        workplace  active          0            6
# 7146      2022-11-23         highRisk  active          0            9
# 7147      2022-11-19         highRisk  active          0           17
# 7148      2022-11-25         highRisk  active          0           36
# 7149      2022-11-30         highRisk  active          0           50
# 7150      2022-11-30         highRisk  active          0           72
# 7151      2022-11-25         highRisk  active          0           25
# 7152      2022-11-26         highRisk  active          0            3
# 7153      2022-12-04        education  active         12           84
# 7154      2022-12-04        education  active          2           89
# 7155      2022-12-03        education  active          0           12
#
#       cases_active  tests  icu  deaths  recovered  \
# 7088            44     59    0       0          0
# 7092           110   1385    0       0          0
# 7098           144    154    0       0          0
# 7100           197    300    0       0          7
# 7101            84    276    0       0          0
# 7102           108    166    0       0          0
# 7105           125    125    0       0          0
# 7106            10     10    0       0          0
# 7107             6      6    0       0          0
# 7108             7      7    0       0          0
# 7109            48    174    0       0          0
# 7110            19     30    0       0          0
# 7111            41    105    0       0          0
# 7112            52     54    0       0          0
# 7113            81    104    0       0          1
# 7114            33     63    0       0          0
# 7115            41    111    0       0          0
# 7116            16     26    0       0          0
# 7117             5     19    0       0          0
# 7118            15    179    0       0          0
# 7119            29     50    0       0          0
# 7120            52     69    0       0          0
# 7121            43     75    0       0          0
# 7122            19     19    0       0          0
# 7123             8      8    0       0          0
# 7124            10     66    0       0          0
# 7125            32    115    0       0          0
# 7126            35     64    0       0          0
# 7127           112    127    0       0          0
# 7128            32     62    0       0          0
# 7129            14     14    0       0          0
# 7130            33     33    0       0          0
# 7131            73     73    0       0          0
# 7132            13     94    0       0          0
# 7133            48     48    0       0          0
# 7134            22     28    0       1          0
# 7135            13     66    0       0          0
# 7136            34     35    0       0          0
# 7137            76    138    0       0          0
# 7138            53     53    0       0          0
# 7139            12     93    0       0          0
# 7140            23     41    0       0          0
# 7141            48     75    0       0          0
# 7142            14     18    0       0          0
# 7143            85    193    0       0          0
# 7144            20     20    0       0          0
# 7145             6     73    0       0          0
# 7146             9      9    0       0          0
# 7147            17     29    0       0          0
# 7148            36     49    0       0          0
# 7149            50     84    0       0          0
# 7150            72     72    0       0          0
# 7151            25     35    0       0          0
# 7152             3     13    0       0          0
# 7153            84    214    0       0          0
# 7154            89    702    0       0          0
# 7155            12     12    0       0          0
#
#                                              summary_bm  \
# 7088  Kluster ini melibatkan pelajar-pelajar asrama ...
# 7092  Kluster ini merupakan kluster berulang untuk k...
# 7098  Kluster ini melibatkan pelajar-pelajar sebuah ...
# 7100  Kluster ini melibatkan pelajar-pelajar sebuah ...
# 7101  Kluster ini merupakan kluster berulang kali ke...
# 7102  Kluster ini merupakan saringan bergejala yang ...
# 7105  Kluster ini merupakan kluster berulang kali ke...
# 7106  Kluster ini merupakan kluster berulang kali ke...
# 7107  Kluster ini melibatkan kakitangan-kakitangan s...
# 7108  Kluster ini melibatkan pelajar-pelajar dan kak...
# 7109  Kluster ini merupakan kluster berulang kali ke...
# 7110  Kluster ini dikenalpasti hasil saringan bergej...
# 7111  Kluster ini melibatkan penghuni-penghuni dan k...
# 7112  Kluster ini merupakan kluster berulang untuk k...
# 7113  Kuster ini dikenalpasti hasil saringan bergeja...
# 7114  Kuster ini merupakan kluster berulang kali ked...
# 7115  Kluster ini merupakan kluster berulang kali ke...
# 7116  Kluster ini melibatkan kakitangan dan pelajar-...
# 7117  Kluster ini melibatkan kakitangan dan pelajar-...
# 7118  Kluster ini merupakan kluster berulang kali ke...
# 7119  Kluster ini merupakan kluster berulang untuk k...
# 7120  Kluster ini merupakan kluster berulang kali ke...
# 7121  Kluster ini melibatkan tahanan-tahanan dan kak...
# 7122  Kluster ini merupakan kluster berulang kali ke...
# 7123  Kluster ini melibatkan pelajar-pelajar dan kak...
# 7124  Kluster ini melibatkan pelajar-pelajar dan kak...
# 7125  Kluster ini melibatkan pelajar-pelajar sebuah ...
# 7126  Kluster ini melibatkan pelajar-pelajar  dan ka...
# 7127  Kluster ini merupakan kluster berulang kali ke...
# 7128  Kluster ini merupakan kluster berulang kali ke...
# 7129  Kluster ini merupakan kluster berulang kali ke...
# 7130  Kluster ini merupakan kluster berulang untuk k...
# 7131  Kluster ini merupakan kluster berulang kali ke...
# 7132  Kluster ini dikenalpasti hasil saringan bersas...
# 7133  Kluster ini merupakan kluster berulang untuk k...
# 7134  Kluster ini merupakan kluster berulang kali ke...
# 7135  Kluster ini merupakan kluster berulang kali ke...
# 7136  Kluster ini merupakan kluster berulang kali ke...
# 7137  Kluster ini merupakan kluster berulang kali ke...
# 7138  Kluster ini merupakan kluster berulang kali ke...
# 7139  Kluster ini merupakan kluster berulang kali ke...
# 7140  Kluster ini merupakan kluster berulang kali ke...
# 7141  Kluster ini melibatkan pelajar-pelajar dan kak...
# 7142  Kluster ini melibatkan pelajar-pelajar sebuah ...
# 7143  Kluster ini melibatkan pelajar-pelajar sebuah ...
# 7144  Kluster ini merupakan kluster berulang kali ke...
# 7145  Kluster ini melibatkan kakitangan sebuah pusat...
# 7146  Kluster ini melibatkan kakitangan sebuah pusat...
# 7147  Kluster ini melibatkan penghuni-penghuni dan k...
# 7148  Kluster ini merupakan kluster berulang kali ke...
# 7149  Kluster ini merupakan kluster berulang kali ke...
# 7150  Kluster ini merupakan kluster berulang untuk k...
# 7151  Kluster ini merupakan kluster berulang untuk k...
# 7152  Kluster ini merupakan kluster berulang kali ke...
# 7153  Kluster ini melibatkan pelajar-pelajar sebuah ...
# 7154  Kluster ini melibatkan pelajar-pelajar sebuah ...
# 7155  Kluster ini melibatkan pelajar-pelajar sebuah ...
#
#                                              summary_en
# 7088  This cluster involves students from an educati...
# 7092  This cluster is the second recurring cluster i...
# 7098  This cluster involves the students of an educa...
# 7100  This cluster involves students from an educati...
# 7101  This cluster is the second repeated cluster id...
# 7102  This cluster is identified as a result of symp...
# 7105  This cluster is the third repeated cluster of ...
# 7106  This cluster is the third recurring cluster in...
# 7107  This cluster involves the staffs of a public a...
# 7108  This cluster involves students and staff from ...
# 7109  This cluster is the second recurring cluster i...
# 7110  This cluster is a symptomatic screening result...
# 7111  This cluster involves residents and staffs of ...
# 7112  This cluster involves students from an educati...
# 7113  This cluster is a symptomatic screening result...
# 7114  This cluster is the second recurring cluster r...
# 7115  This cluster is the third recurring cluster in...
# 7116  This cluster involves the staff and students o...
# 7117  This cluster involves the staff and students o...
# 7118  This cluster is the second repeated cluster in...
# 7119  This is the third recurring cluster involving ...
# 7120  This cluster is the second recurring cluster i...
# 7121  This cluster involves prisoners and staffs of ...
# 7122  This cluster is the second repeated cluster in...
# 7123  This cluster involves the staff and students o...
# 7124  This cluster involves the staff and students o...
# 7125  This cluster involves the students of an educa...
# 7126  This cluster involves the staff and students o...
# 7127  This cluster is the second repeated cluster  r...
# 7128  This cluster is the second repeated cluster in...
# 7129  This cluster is the second repeated cluster in...
# 7130  This cluster is the second repeated cluster in...
# 7131  This fourth recurrent cluster involves the stu...
# 7132  This cluster involves staffs of a logistic com...
# 7133  This cluster is the second repeated cluster  r...
# 7134  This cluster is the third recurring cluster in...
# 7135  This cluster is the second recurring cluster i...
# 7136  This cluster is the second repeated cluster in...
# 7137  This cluster is the third repeated cluster inv...
# 7138  This cluster is the second repeated cluster in...
# 7139  This cluster is the second recurring cluster i...
# 7140  This cluster is the third recurring cluster in...
# 7141  This cluster involves students and staff at an...
# 7142  This cluster involves the students of an educa...
# 7143  This cluster involves students from an educati...
# 7144  This cluster is the second repeated cluster in...
# 7145  This cluster involves the staff of a public ad...
# 7146  This cluster involves the staff of a health ce...
# 7147  This cluster involves residents and staff at a...
# 7148  This cluster is the second recurring cluster i...
# 7149  This cluster is the second recurring cluster i...
# 7150  This is a second recurring cluster involving r...
# 7151  This is a third recurring cluster involving re...
# 7152  This cluster is the fifth repeated cluster inv...
# 7153  This cluster involves students from an educati...
# 7154  This cluster involves the students of an educa...
# 7155  This cluster involves the students of an educa...

# %%
# To check whether there were any deaths in the active cases
active_deaths = df_active['deaths'].sum() 
active_deaths = df_active.loc[df_active['deaths'] == int(active_deaths)] 
active_deaths
# Out:
#                      cluster         state              district  \
# 7134  KLUSTER LORONG KAPAL 3  PULAU PINANG  SEBERANG PERAI UTARA
#
#      date_announced date_last_onset  category  status  cases_new  cases_total  \
# 7134     2022-11-13      2022-11-12  highRisk  active          0           23
#
#       cases_active  tests  icu  deaths  recovered  \
# 7134            22     28    0       1          0
#
#                                              summary_bm  \
# 7134  Kluster ini merupakan kluster berulang kali ke...
#
#                                              summary_en
# 7134  This cluster is the third recurring cluster in...

# %%
# To view the number of deaths according to Category in a pivot table
pivot = df_1.pivot_table(index = 'category', values ='deaths', aggfunc = sum)
pivot
pivot = pivot.sort_values('deaths') #----To sort the values in ascending order
pivot
# Out:
#                  deaths
# category
# import               15
# education            23
# detentionCentre      53
# religious           161
# highRisk            446
# workplace           554
# community           697

# %%
# To plot a bar chart to visualise death distribution according to categories
pivot.plot(kind = 'bar', xlabel = 'Category', ylabel = 'Deaths', color = 'green', legend = False)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Deaths'>

# %%
pivot.boxplot()
# Out:
# <AxesSubplot:>

# %%
df_1['deaths'].plot(kind = 'density')
plt.show()

# %%
pivot.plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_1.skew(numeric_only = True)
# Out:
# cases_new       81.561762
# cases_total     14.940816
# cases_active    20.779530
# tests           22.116428
# icu             24.363576
# deaths          13.469227
# recovered       14.975666
# dtype: float64
